# %% [markdown]
# Descripció:
# Anem a practicar i a familiaritzar-nos amb l'estructura de Matrius, dimensió, forma, vectorització i Broadcasting .

# %% [markdown]
# # Nivell 1

# %% [markdown]
# ## - Exercici 1

# %% [markdown]
# Crea un np.array d'una dimensió, que inclogui l'almenys 8 nombres sencers, data type int64. Mostra la dimensió i la forma de la matriu. .

# %%
import numpy as np

array = np.array([1,3,5,2,4,7,8,9,120], dtype=np.uint64)
 
print('La dimension del array es: ', array.ndim)
print('y la forma es:  ', array.shape)
# Out:
# La dimension del array es:  1
# y la forma es:   (9,)

# %% [markdown]
# ## - Exercici 2

# %% [markdown]
# De la matriu de l'exercici 1, calcula el valor mitjà dels valors introduïts.

# %%
print('La mitjana és: ', round(array.mean(),2))
# Out:
# La mitjana és:  17.67

# %% [markdown]
# ## - Exercici 3

# %% [markdown]
# Crea una matriu bidimensional amb una forma de 5 x 5. Extreu el valor màxim de la matriu, i els valors màxims de cadascun dels seus eixos.

# %%
# Genero un array aleatori:

np.random.seed(0)
array5x5 = np.random.rand(5,5)
array5x5
# Out:
# array([[0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ],
#        [0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152],
#        [0.79172504, 0.52889492, 0.56804456, 0.92559664, 0.07103606],
#        [0.0871293 , 0.0202184 , 0.83261985, 0.77815675, 0.87001215],
#        [0.97861834, 0.79915856, 0.46147936, 0.78052918, 0.11827443]])

# %%
maximo =array5x5.max()
print('EL màxim és: ', maximo)

maximo =array5x5.max()
print('EL màxim és: ', maximo)
# Out:
# EL màxim és:  0.978618342232764
# EL màxim és:  0.978618342232764

# %%
# El valor maxi del eix X es
dd=array5x5.max(axis=0)

print("El valor maxim de l'eix Y (columna) son: ", dd)

dd=array5x5.max(axis=1)

print("El valor maxim de l'eix X (fila) son: ", dd)
#dd.max(axis=0)
# Out:
# El valor maxim de l'eix Y (columna) son:  [0.97861834 0.79915856 0.891773   0.96366276 0.87001215]
# El valor maxim de l'eix X (fila) son:  [0.71518937 0.96366276 0.92559664 0.87001215 0.97861834]

# %% [markdown]
# # Nivell 2

# %% [markdown]
# ## - Exercici 4

# %% [markdown]
# Mostreu-me amb exemples de diferents matrius, la regla fonamental de Broadcasting que diu : "les matrius es poden transmetre / broadcast si les seves dimensions coincideixen o si una de les matrius té una mida d'1".
#
# ![numpy_broadcasting.png](attachment:numpy_broadcasting.png)

# %%
A = np.array([15, 7, 3, 1])
B = np.array([60, 50, 30, 30])
 
# array are compatible because of same Dimension
C = A * B
print (C)
# Out:
# [900 350  90  30]

# %%
#Genero nombres aleatoris sensers
A1 = np.random.randint(10, size= (5,5))
A2 = np.random.randint(10, size= (5,5))
A_multiplicat = A1*A2
print(A1)
print()
print(A2)
print(' La multiplicación es: ')
print(A_multiplicat)
# Out:
# [[0 1 9 9 0]
#  [4 7 3 2 7]
#  [2 0 0 4 5]
#  [5 6 8 4 1]
#  [4 9 8 1 1]]
#
# [[7 9 9 3 6]
#  [7 2 0 3 5]
#  [9 4 4 6 4]
#  [4 3 4 4 8]
#  [4 3 7 5 5]]
#  La multiplicación es:
# [[ 0  9 81 27  0]
#  [28 14  0  6 35]
#  [18  0  0 24 20]
#  [20 18 32 16  8]
#  [16 27 56  5  5]]

# %%
#Genero nombres aleatoris sensers
A1 = np.random.randint(10, size= (5,5))
A2 = np.random.randint(10, size= (1,5))
A_multiplicat = A1+A2
print(A1)
print()
print(A2)
print(' La Suma es: ')
print(A_multiplicat)
# Out:
# [[0 1 5 9 3]
#  [0 5 0 1 2]
#  [4 2 0 3 2]
#  [0 7 5 9 0]
#  [2 7 2 9 2]]
#
# [[3 3 2 3 4]]
#  La Suma es:
# [[ 3  4  7 12  7]
#  [ 3  8  2  4  6]
#  [ 7  5  2  6  6]
#  [ 3 10  7 12  4]
#  [ 5 10  4 12  6]]

# %%
#Genero nombres aleatoris sensers

A1 = np.random.randint(10, size= (5,1))
A2 = np.random.randint(10, size= (1,5))
A_multiplicat = A1+A2
print(A1)
print()
print(A2)
print('\n\n La Suma es: ')
print(A_multiplicat)
# Out:
# [[1]
#  [2]
#  [9]
#  [1]
#  [4]]
#
# [[6 8 2 3 0]]
#
#
#  La Suma es:
# [[ 7  9  3  4  1]
#  [ 8 10  4  5  2]
#  [15 17 11 12  9]
#  [ 7  9  3  4  1]
#  [10 12  6  7  4]]

# %% [markdown]
# ## - Exercici 5

# %% [markdown]
# Utilitza la Indexació per extreure els valors d'una columna i una fila de la matriu. I suma els seus valors.

# %%
A1 = np.random.randint(10, size= (5,5))
columna1= A1[0]
fila1 = A1[:,1]
print(A1)
print('\n')
print('  ',columna1)
print('+ ',fila1)
print('\nLa suma és: ', columna1 +fila1)
# Out:
# [[5 3 9 1 5]
#  [3 1 3 4 1]
#  [0 9 4 6 3]
#  [6 6 3 0 3]
#  [8 6 9 3 6]]
#
#
#    [5 3 9 1 5]
# +  [3 1 9 6 6]
#
# La suma és:  [ 8  4 18  7 11]

# %% [markdown]
# ## - Exercici 6

# %% [markdown]
# Mask la matriu anterior, realitzeu un càlcul booleà vectoritzat, agafant cada element i comprovant si es divideix uniformement per quatre.
#
# Això retorna una matriu de mask de la mateixa forma amb els resultats elementals del càlcul.

# %%
print(A1)
print()
A3 = (A1%4==0)
print(A3)
# Out:
# [[0 6 0 6 3]
#  [3 8 8 8 2]
#  [3 2 0 8 8]
#  [3 8 2 8 4]
#  [3 0 4 3 6]]
#
# [[ True False  True False False]
#  [False  True  True  True False]
#  [False False  True  True  True]
#  [False  True False  True  True]
#  [False  True  True False False]]

# %% [markdown]
# ## Exercici 7

# %% [markdown]
# A continuació, utilitzeu aquesta màscara per indexar a la matriu de números original. Això fa que la matriu perdi la seva forma original, reduint-la a una dimensió, però encara obteniu les dades que esteu cercant.

# %% [markdown]
# # Nivell 3

# %% [markdown]
# Carregareu qualsevol imatge (jpg, png ..) amb Matplotlib. adoneu-vos que les imatges RGB (Red, Green, Blue) són realment només amplades × alçades × 3 matrius (tres canals Vermell, Verd i Blau), una per cada color de nombres enters int8,
#
# manipuleu aquests bytes i torneu a utilitzar Matplotlib per desar la imatge modificada un cop hàgiu acabat.
#
# Ajuda:Importeu, import matplotlib.image as mpimg. estudieu el metodde mpimg.imread(()

# %% [markdown]
# ![CIBERNARIUM.jpg](attachment:CIBERNARIUM.jpg)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as img
from google.colab import files
uploaded = files.upload()

#image = img.imread(r'F:\03.- Data Science IT Academy\imagenes\CIBERNARIUM.jpg')
image = img.imread(r'/content/casa.jpg')
# Out:
#      <input type="file" id="files-8f368fe4-b27f-4701-b44c-e3a43402e478" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8f368fe4-b27f-4701-b44c-e3a43402e478">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# cargo la imagen
 
image = img.imread(r'/content/casa.jpg')

plt.imshow(image)
plt.show()

# %%
# !pwd
# Out:
# /content

# %%
#Tamaño de la imagen
print('Pixels en Horizontal, Vertical y nº de colores: ', image.shape)
# Out:
# Pixels en Horizontal, Vertical y nº de colores:  (1333, 2000, 3)

# %%
columnasFijas = 100 # Cantidad de columnas que no quiero que se modifiquen
deformacionImagen = np.random.rand(654, columnasFijas,3)
print(deformacionImagen.shape)

#deformacionImagen= np.random.randint(10, size = (654, columnasFijas,3))
#deformacionImagen = np.ones(654, columnasFijas, 3)

a = np.zeros((654, 654, 3), int)
np.fill_diagonal(a, 1)
print(a)
print(deformacionImagen.shape)
# Out:
# (654, 100, 3)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-b4cd95e6168b> in <module>()
#       8
#       9 a = np.zeros((654, 654, 3), int)
# ---> 10 np.fill_diagonal(a, 1)
#      11 print(a)
#      12 print(deformacionImagen.shape)
#
# <__array_function__ internals> in fill_diagonal(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/index_tricks.py in fill_diagonal(a, val, wrap)
#     903         # all dimensions equal, so we check first.
#     904         if not alltrue(diff(a.shape) == 0):
# --> 905             raise ValueError("All dimensions of input must be of equal length")
#     906         step = 1 + (cumprod(a.shape[:-1])).sum()
#     907
#
# ValueError: All dimensions of input must be of equal length

# %%
ff = image.copy()
ff[100:25, 0:125] = [110, 0, 0]

#Error = np.append(image, data, axis=1)
#imagenDeformada = image - data


plt.imshow(ff)
plt.show()

# %%
w, h = 900, 654
data = np.zeros((h, w, 3), dtype=np.uint8)
data[100:25, 0:125] = [0, 100, 250]

#Error = np.append(image, data, axis=1)
imagenDeformada = image - data


plt.imshow(imagenDeformada)
plt.show()

print(data.shape)
# Out:
# (654, 900, 3)

# %%
a = np.zeros((3, 3), int)
b= np.fill_diagonal(a, 1)
print(a)
# Out:
# [[1 0 0]
#  [0 1 0]
#  [0 0 1]]

# %%
 # manipuleu aquests bytes i torneu a utilitzar Matplotlib per desar la imatge modificada un cop hàgiu acabat.
    
arrayCeros = np.zeros((654,900-columnasFijas,3))
print('Forma arrayCeros: ', arrayCeros.shape)

Error = np.append(deformacionImagen, arrayCeros, axis=1)
print('Forma Error:      ', Error.shape)
# Out:
# Forma arrayCeros:  (654, 800, 3)
# Forma Error:       (654, 900, 3)

# %%
# SUmo la imgen original + un array con bits deformados
imagenDeformada = image + Error
plt.imshow(imagenDeformada)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
arrayUnos = np.ones((654,900-columnasFijas,3))
print('Forma arrayCeros: ', arrayCeros.shape)

Error = np.append(deformacionImagen, arrayUnos, axis=1)
print('Forma Error:      ', Error.shape)
imagenDeformada = image + Error
plt.imshow(imagenDeformada)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Forma arrayCeros:  (654, 800, 3)
# Forma Error:       (654, 900, 3)

# %% [markdown]
# ## - Exercici 8

# %% [markdown]
# Mostreu-me a veure que passa quan eliminem el canal G Verd o B Blau.
#
# Mostreu-me a veure què passa quan eliminem el canal G Verd o B Blau. Hauries d'utilitzar la indexació per seleccionar el canal que voleu anul·lar.
#
# Utilitzar el mètode, mpimg.imsave () de la llibreria importada, per guardar les imatges modificades i que haureu de pujar al vostre repositori a github.

# %%
image_red=np.copy(image) # creo una copia de la imagen para preservar la original
image_red[:,:,1]=0
image_red[:,:,2]=0
plt.title("image rojo")
plt.imshow(image_red)

# %%
image_red_green=np.copy(image) # creo una copia de la imagen para preservar la original
image_red_green[:,:,2]=0
plt.title("image_ sin canal azul")
plt.imshow(image_red_green)

# %%
image_blue_green=np.copy(image) # creo una copia de la imagen para preservar la original
image_blue_green[:,:,0]=0
plt.title("image_ sin canal rojo")
plt.imshow(image_blue_green)
